# %%
import pandas as pd

# Load CSV from './TMDB_all_movies.csv'
df = pd.read_csv('./TMDB_all_movies.csv')

# Leave only the columns ['id', 'title', 'vote_average', 'status', 'release_date', 'budget', 'revenue', 'popularity', 'genres', 'cast', 'director', 'production_companies']
df = df[['id', 'title', 'vote_average', 'status', 'release_date', 'budget', 'revenue', 'popularity', 'genres', 'cast', 'director', 'production_companies']]

# Drop rows with NaN values
df = df.dropna()

# Save the result to './TMDB_all_movies_cleaned.csv'
df.to_csv('./TMDB_all_movies_cleaned.csv', index=False)

# %%
# Print the first 5 rows
#print(df.head())

# Show some examples of movies with a popularity between 0 and 5, sorted by popularity
print(df[(df['popularity'] >= 25) & (df['popularity'] < 30)].sort_values(by='popularity', ascending=False).head())

# Make an histogram of the 'popularity' column, with 100 bins, with an interval of 5 ([0, 5[, [5, 10[, [10, 15[, etc.)])
df['popularity'].hist(bins=100, range=(0, 40), figsize=(20, 10))

# Remove movies with a popularity below 20
df = df[df['popularity'] >= 15]

# Remove movies with a budget of 0
df = df[df['budget'] > 0]

# Save the result to './TMDB_all_movies_cleaned_2.csv'
df.to_csv('./TMDB_all_movies_cleaned_2.csv', index=False)
# Out:
#             id                                  title  vote_average    status  \
# 289208  428449                          A Ghost Story         7.100  Released
# 4679      9488  Spy Kids 2: The Island of Lost Dreams         5.627  Released
# 6777     11863                                   Jade         5.400  Released
# 7661     13283          Barbie as the Island Princess         7.200  Released
# 40283    58496                                  Senna         8.100  Released
#
#        release_date      budget      revenue  popularity  \
# 289208   2017-04-24    100000.0    1929659.0      29.999
# 4679     2002-08-07  38000000.0  119700000.0      29.995
# 6777     1995-10-13  50000000.0    9851610.0      29.984
# 7661     2007-09-17         0.0          0.0      29.968
# 40283    2010-10-07         0.0    8212430.0      29.964
#
#                                                    genres  \
# 289208                                     Drama, Fantasy
# 4679    Action, Adventure, Family, Comedy, Science Fic...
# 6777                                    Mystery, Thriller
# 7661                                    Animation, Family
# 40283                                         Documentary
#
#                                                      cast          director  \
# 289208  Sonia Acevedo, Brandi Price, Randy E. Aguebor,...      David Lowery
# 4679    Mark Turner, Brian Thornton, Ron Hayden, Steve...  Robert Rodriguez
# 6777    Kenneth Tigar, Harold Morrison, Nicholas Tarvi...  William Friedkin
# 7661    Britt McKillip, Andrea Martin, Terry Klassen, ...   Greg Richardson
# 40283   Jackie Stewart, Nigel Mansell, John Bisignano,...      Asif Kapadia
#
#                                      production_companies
# 289208  Sailor Bear, Zero Trans Fat Productions, Ideam...
# 4679                Dimension Films, Troublemaker Studios
# 6777    Paramount Pictures, Robert Evans Company, Adel...
# 7661                      Rainmaker Entertainment, Mattel
# 40283   Universal Pictures, StudioCanal, Working Title...
